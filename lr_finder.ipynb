# %%
import torch
import torch.nn as nn
import utils as ut
from torch_lr_finder import LRFinder
from efficientnet_pytorch import EfficientNet
from torch.utils.data import Dataset, DataLoader
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# dataset and data loader
dstr = ut.RumexDataset("data/10m/256/train/")
dltr = ut.train_loader(dstr, bs=)
loss_fn = nn.CrossEntropyLoss(reduction="mean")

# %%
ut.set_seed(seed)
model_name = 'efficientnet'
model = ut.RumexNet(model_name)
optimizer = torch.optim.Adam(model.parameters(), lr=1.0e-7)
lr_finder = LRFinder(model, optimizer, loss_fn)
lr_finder.range_test(dltr, end_lr=1, num_iter=100, step_mode="exp")
lr_finder.plot()
# Out:
# Loaded pretrained weights for efficientnet-b0
#  91%|█████████ | 91/100 [08:34<00:50,  5.66s/it]Stopping early, the loss has diverged
# Learning rate search finished. See the graph with {finder_name}.plot()
#
# LR suggestion: steepest gradient
# Suggested LR: 2.42E-03
# (<AxesSubplot:xlabel='Learning rate', ylabel='Loss'>, 0.002420128264794383)

# %%
ut.set_seed(seed)
model_name = 'resnet'
model = ut.RumexNet(model_name)
optimizer = torch.optim.Adam(model.parameters(), lr=1.0e-7)
lr_finder = LRFinder(model, optimizer, loss_fn)
lr_finder.range_test(dltr, end_lr=10, num_iter=100, step_mode="exp")
lr_finder.plot()
# Out:
#  91%|█████████ | 91/100 [12:54<01:16,  8.51s/it]Stopping early, the loss has diverged
# Learning rate search finished. See the graph with {finder_name}.plot()
#
# LR suggestion: steepest gradient
# Suggested LR: 2.48E-04
# (<AxesSubplot:xlabel='Learning rate', ylabel='Loss'>, 0.0002477076355991711)

# %%
ut.set_seed(seed)
model_name = 'densenet'
model = ut.RumexNet(model_name)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-7)
lr_finder = LRFinder(model, optimizer, loss_fn)
lr_finder.range_test(dltr, end_lr=1, num_iter=100, step_mode="exp")
lr_finder.plot()
# Out:
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /u/21/hiremas1/unix/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 73.8MB/s]
#  99%|█████████▉| 99/100 [13:23<00:08,  8.11s/it]Stopping early, the loss has diverged
# Learning rate search finished. See the graph with {finder_name}.plot()
#
# LR suggestion: steepest gradient
# Suggested LR: 5.59E-04
# (<AxesSubplot:xlabel='Learning rate', ylabel='Loss'>, 0.0005590810182512224)

# %%
ut.set_seed(seed)
model_name = 'mobilenet'
model = ut.RumexNet(model_name)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-7)
lr_finder = LRFinder(model, optimizer, loss_fn)
lr_finder.range_test(dltr, end_lr=1, num_iter=100, step_mode="exp")
lr_finder.plot()
# Out:
# 100%|██████████| 100/100 [05:14<00:00,  3.14s/it]
# Learning rate search finished. See the graph with {finder_name}.plot()
# LR suggestion: steepest gradient
# Suggested LR: 4.04E-04
# (<AxesSubplot:xlabel='Learning rate', ylabel='Loss'>, 0.0004037017258596554)

# %%
ut.set_seed(seed)
model_name = 'shufflenet'
model = ut.RumexNet(model_name)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-7)
lr_finder = LRFinder(model, optimizer, loss_fn)
lr_finder.range_test(dltr, end_lr=1, num_iter=100, step_mode="exp")
lr_finder.plot()
# Out:
#  81%|████████  | 81/100 [00:47<00:11,  1.70it/s]Stopping early, the loss has diverged
# Learning rate search finished. See the graph with {finder_name}.plot()
# LR suggestion: steepest gradient
# Suggested LR: 5.34E-03
# (<AxesSubplot:xlabel='Learning rate', ylabel='Loss'>, 0.005336699231206315)

# %%
ut.set_seed(seed)
model_name = 'mnasnet'
model = ut.RumexNet(model_name)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-7)
lr_finder = LRFinder(model, optimizer, loss_fn)
lr_finder.range_test(dltr, end_lr=10, num_iter=100, step_mode="exp")
lr_finder.plot()
# Out:
# Downloading: "https://download.pytorch.org/models/mnasnet1.0_top1_73.512-f206786ef8.pth" to /u/21/hiremas1/unix/.cache/torch/hub/checkpoints/mnasnet1.0_top1_73.512-f206786ef8.pth
# 100%|██████████| 16.9M/16.9M [00:00<00:00, 19.9MB/s]
#  91%|█████████ | 91/100 [04:15<00:25,  2.81s/it]Stopping early, the loss has diverged
# Learning rate search finished. See the graph with {finder_name}.plot()
#
# LR suggestion: steepest gradient
# Suggested LR: 2.78E-03
# (<AxesSubplot:xlabel='Learning rate', ylabel='Loss'>, 0.0027825594022071257)
